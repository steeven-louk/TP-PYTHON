# %%
from random import randint
import random


populations = [
    { "id" : 0, "name" : "Alan" },
    { "id" : 1, "name" : "Albert" },
    { "id" : 2, "name" : "Jhon" },
    { "id" : 3, "name" : "Brice" },
    { "id" : 4, "name" : "Alexendra" },
    { "id" : 5, "name" : "Brad" },
    { "id" : 6, "name" : "Carl" },
    { "id" : 7, "name" : "Dallas" },
    { "id" : 8, "name" : "Dennis" },
    { "id" : 9, "name" : "Edgar" },
    { "id" : 10, "name" : "Erika" },
    { "id" : 11, "name" : "Isaac" },
    { "id" : 13, "name" : "Brice" },
    { "id" : 14, "name" : "Alice" },
    { "id" : 15, "name" : "Sophia" },
    { "id" : 16, "name" : "Rasmus" },
    { "id" : 18, "name" : "Taylor" },
    { "id" : 19, "name" : "Olivia" },
    { "id" : 20, "name" : "Jessica" },
    { "id" : 21, "name" : "Anna" },
    { "id" : 22, "name" : "Samantha" },
    { "id" : 23, "name" : "Grace" },
    { "id" : 24, "name" : "Anna" },
    { "id" : 25, "name" : "Alexis" },
    { "id" : 26, "name" : "Madison" },
    { "id" : 27, "name" : "Nicole" },
    { "id" : 28, "name" : "Amanda" },
    { "id" : 29, "name" : "Haley" }  
]

# ajout de lenChar
for person in populations:
    person["lenChar"] = len(person["name"])
    # print(person)
    
# ajout de rate
for person in populations:
    person["rate"] = randint(1,100)
    # print(person)
    
# tri par champ rate
tri_population = sorted(populations, key=lambda person:person['rate'], reverse=True)
# print(tri_population)

# recuperation des 4 meilleur
quatre_meilleur = tri_population[1:4]
# print(qutre_meilleur)


# multiplication du taux
for person in populations:
    person["rate"] += 1.001
    # print(person)
    
def tri_random_person(population):
    person = random.choice(population)
    return person

tri_person = tri_random_person(populations)
# print(tri_person)

s = sorted(populations, key=lambda person: person["rate"])

for person in s:
   s =[( person["name"], person["rate"])]
#    print(f"la liste de tuple est\n{s}")
   
#ordonner par partie

valuer_central = s[len(s) // 2]
# print(f"la valeur central  est \n{valuer_central}")



#Partitionnement en quatre parties
longueur = len(s)
partie1 = s[:longueur // 4]
partie2 = s[longueur // 4: 2 * longueur // 4]
partie3 = s[2 * longueur // 4: 3 * longueur // 4]
partie4 = s[3 * longueur // 4:]

# Affichage des parties
print(f"Partie 1: {partie1}")
print(f"Partie 2: {partie2}")
print(f"Partie 3: {partie3}")
print(f"Partie 4: {partie4}")
# Out:
# Partie 1: []
# Partie 2: []
# Partie 3: []
# Partie 4: [('Anna', 96.09599999999999)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 90
#      87 print(f"Partie 4: {partie4}")
#      89 # Calcul de la moyenne
# ---> 90 moyenne = sum(s) / len(longueur)
#      92 # # Affichage de la moyenne
#      93 print(f"Moyenne des taux : {moyenne}")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'
